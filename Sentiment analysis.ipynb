# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/Sony_Pictures_Entertainment_Motion_Picture_Group"

# %%
r = requests.get(url)
data = r.text
data
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Sony Pictures Entertainment Motion Picture Group - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"Xl-6SApAMEwAAKUVmh4AAACT","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Sony_Pictures_Entertainment_Motion_Picture_Group","wgTitle":"Sony Pictures Entertainment Motion Picture Group","wgCurRevisionId":943877202,"wgRevisionId":943877202,"wgArticleId":3087502,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGr
# ...

# %%
soup = BeautifulSoup(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-177ead4d8576> in <module>
# ----> 1 soup = BeautifulSoup(data)
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     277          self.contains_replacement_characters) in (
#     278              self.builder.prepare_markup(
# --> 279                  markup, from_encoding, exclude_encodings=exclude_encodings)):
#     280             self.reset()
#     281             try:
#
# ~\Anaconda3\lib\site-packages\bs4\builder\_lxml.py in prepare_markup(self, markup, user_specified_encoding, exclude_encodings, document_declared_encoding)
#     119         try_encodings = [user_specified_encoding, document_declared_encoding]
#     120         detector = EncodingDetector(
# ...

# %%
table = soup.find_all('table')[4]

# %%
table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Title
# </th>
# <th>Release date
# </th>
# <th>Notes
# </th></tr>
# <tr>
# <td><i><a href="/wiki/Blondie_(1938_film)" title="Blondie (1938 film)">Blondie</a></i></td>
# <td>1938–1950</td>
# <td>co-production with <a href="/wiki/King_Features_Syndicate" title="King Features Syndicate">King Features Entertainment</a>
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Five_Little_Peppers" title="Five Little Peppers">Five Little Peppers</a></i></td>
# <td>1939–1940</td>
# <td>
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Boston_Blackie" title="Boston Blackie">Boston Blackie</a></i></td>
# <td>1941–1949</td>
# <td>
# </td></tr>
# <tr>
# <td><i><a href="/wiki/Crime_Doctor_(film)" title="Crime Doctor (film)">Crime Doctor</a></i></td>
# <td>1943–1949</td>
# <td>
# </td></tr>
# <tr>
# <td><i><a href="/wiki/The_Whistler_(1944_film)" title="The Whistler (1944 film)">The Whistler</a></i></td>
# <td>1944–1948</td>
# <td>
# </td></tr>
# <tr>
# ...

# %%
rows = table.find_all('tr')[1:]

rows
# Out:
# [<tr>
#  <td><i><a href="/wiki/Blondie_(1938_film)" title="Blondie (1938 film)">Blondie</a></i></td>
#  <td>1938–1950</td>
#  <td>co-production with <a href="/wiki/King_Features_Syndicate" title="King Features Syndicate">King Features Entertainment</a>
#  </td></tr>, <tr>
#  <td><i><a href="/wiki/Five_Little_Peppers" title="Five Little Peppers">Five Little Peppers</a></i></td>
#  <td>1939–1940</td>
#  <td>
#  </td></tr>, <tr>
#  <td><i><a href="/wiki/Boston_Blackie" title="Boston Blackie">Boston Blackie</a></i></td>
#  <td>1941–1949</td>
#  <td>
#  </td></tr>, <tr>
#  <td><i><a href="/wiki/Crime_Doctor_(film)" title="Crime Doctor (film)">Crime Doctor</a></i></td>
#  <td>1943–1949</td>
#  <td>
#  </td></tr>, <tr>
#  <td><i><a href="/wiki/The_Whistler_(1944_film)" title="The Whistler (1944 film)">The Whistler</a></i></td>
#  <td>1944–1948</td>
#  <td>
#  </td></tr>, <tr>
#  <td><i><a href="/wiki/Rusty_(film_series)" title="Rusty (film series)">Rusty</a></i></td>
#  <td>1945–1949</td>
# ...

# %%
df=pd.DataFrame();

# %%
for row in rows:
    #for i in range(len(rows)):
    column.append(row.find_all('td'))

    
    
    #column

# %%
column
# Out:
# [[<td><i><a href="/wiki/Blondie_(1938_film)" title="Blondie (1938 film)">Blondie</a></i></td>,
#   <td>1938–1950</td>,
#   <td>co-production with <a href="/wiki/King_Features_Syndicate" title="King Features Syndicate">King Features Entertainment</a>
#   </td>],
#  [<td><i><a href="/wiki/Five_Little_Peppers" title="Five Little Peppers">Five Little Peppers</a></i></td>,
#   <td>1939–1940</td>,
#   <td>
#   </td>],
#  [<td><i><a href="/wiki/Boston_Blackie" title="Boston Blackie">Boston Blackie</a></i></td>,
#   <td>1941–1949</td>,
#   <td>
#   </td>],
#  [<td><i><a href="/wiki/Crime_Doctor_(film)" title="Crime Doctor (film)">Crime Doctor</a></i></td>,
#   <td>1943–1949</td>,
#   <td>
#   </td>],
#  [<td><i><a href="/wiki/The_Whistler_(1944_film)" title="The Whistler (1944 film)">The Whistler</a></i></td>,
#   <td>1944–1948</td>,
#   <td>
#   </td>],
#  [<td><i><a href="/wiki/Rusty_(film_series)" title="Rusty (film series)">Rusty</a></i></td>,
#   <td>1945–1949</td>,
#   <td>
# ...

# %%
len(rows)
# Out:
# 59

# %%
data = {
    'wikitable sortable jquery tablesorter': [],
    'year1938-1950' : [],
    'year1939-1940' : [],
    'year1941-1949' : [],
    'year1943-1949' : [],
     'year1944-1948' : [],
     'year1945-1949' : [],
     'year1948-1956' : [],
     'year1981-2000' : [],
     'year1982-present' : [],
     'year1984-present' : [],
    'year1984-present' : [],
    'year1989-1993' : [],
    'year1991-1994' : [],
    'year1993-present' : [],
    'year1994-1998' : [],
    'year1995-present' : [],
    'year1995-present' : [],
    'year1995-2009' : [],
    'year1997-present': [],
    'year1997-2006' : [],
    'year1997-present' : [],
    'year1998-2005' : [],
    'year1998-2010' : [],
    'year1998-2005' : [],
    'year1999-present' : [],
    'year1999-present' : [],
    'year2000-2006' : [],
    'year2000-present' : [],
    'year2001-present' : [],
    'year2002-2016' : [],
    'year2002-present' : [],
    'year2002-pesent' : [],
    'year2003-2007' : [],
    'year2003-present' : [],
    'year2003-2016' : [],
    'year2004-present' : [],
    'year2005-present' : [],
    'year2005-2009' : [],
    'year2005-2011' : [],
    'year2006-2016' : [],
    'year2006-2016' : [],
    'year2006-2015' : [],
    'year2007-2011' : [],
    'year2007-2012' : [],
    'year2007-2017' : [],
    'year2008-2011' : [],
    'year2009-present' : [],
    'year2011-present' : [],
    'year2011-2017' : [],
    'year2012-present' : [],
    'year2012-present' : [],
    'year2013-present' : [],
    'year2014-present' : [],
    'year2015-present' : [],
    'year2016-present' : [],
    'year2018-present' : [],
    'year2018-present' : [],
    'year2018-present' : []
}

# %%
movieData = pd.DataFrame( data )

# %%
movieData.to_csv("Sony_Pictures_Entertainment_Motion_Picture_Group.csv")

# %% [markdown]
# movieData = read_csv

# %%
movieData.to_csv("Sony_Pictures_Entertainment_Motion_Picture_Group.csv")

# %%
movieData
# Out:
# Empty DataFrame
# Columns: [wikitable sortable jquery tablesorter, year1938-1950, year1939-1940, year1941-1949, year1943-1949, year1944-1948, year1945-1949, year1948-1956, year1981-2000, year1982-present, year1984-present, year1989-1993, year1991-1994, year1993-present, year1994-1998, year1995-present, year1995-2009, year1997-present, year1997-2006, year1998-2005, year1998-2010, year1999-present, year2000-2006, year2000-present, year2001-present, year2002-2016, year2002-present, year2002-pesent, year2003-2007, year2003-present, year2003-2016, year2004-present, year2005-present, year2005-2009, year2005-2011, year2006-2016, year2006-2015, year2007-2011, year2007-2012, year2007-2017, year2008-2011, year2009-present, year2011-present, year2011-2017, year2012-present, year2013-present, year2014-present, year2015-present, year2016-present, year2018-present]
# Index: []
#
# [0 rows x 50 columns]

# %%
movieData.columns = ['year1945-1949','year1981-2000']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-52adbdec1d6e> in <module>
# ----> 1 movieData.columns = ['year1945-1949','year1981-2000']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# ...

# %%
#import libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#send request
url = "https://en.wikipedia.org/wiki/List_of_Sony_Pictures_Animation_productions"

page=requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
#read data
table = soup.find_all('table')

table
# Out:
# [<table class="box-Unreferenced_section plainlinks metadata ambox ambox-content ambox-Unreferenced" role="presentation"><tbody><tr><td class="mbox-image"><div style="width:52px"><a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></div></td><td class="mbox-text"><div class="mbox-text-span">This section <b>does not <a href="/wiki/Wikipedia:Citing_sources" title="Wikipedia:Citing sources">cite</a> any <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">sources</a></b>.<span class="hide-when-compact"> Please help <a class="external text" href=
# ...

# %%
import pandas as pd

# %%
#set notebook display to show all columns and rows 
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
#read the table
table = pd.read_html('https://en.wikipedia.org/wiki/List_of_Sony_Pictures_Animation_productions', index_col=1)
#show the output
table[1]
# Out:
#                                                    0                   2                                          3                                                  4                         5                  6                 7                8           9
# 1
# Title                                              #        Release date                                Director(s)                                 Co-production with        Animation services  Budget (millions)  Gross (millions)  Rotten Tomatoes  Metacritic
# Open Season                                        1  September 29, 2006                    Jill CultonRoger Allers                                  Columbia Pictures  Sony Pictures Imageworks                $85              $197              48%          49
# ...

# %%
# !pip install lxml

# %%
table = pd.read_html('https://en.wikipedia.org/wiki/List_of_Sony_Pictures_Animation_productions', index_col=1)
table[2]
# Out:
#                                                     0                   2                   3             4                                                  5                         6
# 1
# Title                                               #        Release date         Director(s)        Ref(s)                                 Co-production with        Animation services
# Connected                                          20  September 18, 2020      Michael Rianda  [2][3][4][5]  Columbia PicturesLord Miller ProductionsMedia ...  Sony Pictures Imageworks
# Offward                                            21   December 11, 2020                 TBA        [6][7]                                  Columbia Pictures                       TBA
# Wish Dragon                                        22                2020     Chris Appelhans        [7][6]  Columbia PicturesBeijing Sparkle Roll Media Co...                   Base FX
# ...

# %%
df = pd.read_json("C:\\Users\\Admin\\Desktop\\Data Science\\Social Media Analysis\\Social Media Analytics Assignment\\tweets.json", lines=True)

# %%
df.head()
# Out:
#    contributors  coordinates          created_at display_text_range                                           entities                                  extended_entities extended_tweet  favorite_count  favorited filter_level  geo                   id               id_str in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  in_reply_to_user_id_str  is_quote_status lang place  possibly_sensitive  quote_count quoted_status  quoted_status_id  quoted_status_id_str quoted_status_permalink  reply_count  retweet_count  retweeted                                   retweeted_status                                             source                                               text            timestamp_ms  truncated                                               user
# ...

# %%
df.drop(columns=['entities'], inplace=True)
df.head()
# Out:
#    contributors  coordinates          created_at display_text_range                                  extended_entities extended_tweet  favorite_count filter_level                   id               id_str in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  in_reply_to_user_id_str  is_quote_status lang place  possibly_sensitive  quote_count quoted_status  quoted_status_id  quoted_status_id_str quoted_status_permalink  reply_count  retweet_count  retweeted                                   retweeted_status                                             source                                               text            timestamp_ms  truncated                                               user
# ...

# %%
df.drop(columns=['text'], inplace=True)
df.head()
# Out:
#    contributors  coordinates          created_at display_text_range                                  extended_entities extended_tweet  favorite_count filter_level                   id               id_str in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  in_reply_to_user_id_str  is_quote_status lang place  possibly_sensitive  quote_count quoted_status  quoted_status_id  quoted_status_id_str quoted_status_permalink  reply_count  retweet_count  retweeted                                   retweeted_status                                             source            timestamp_ms  truncated                                               user
# ...
